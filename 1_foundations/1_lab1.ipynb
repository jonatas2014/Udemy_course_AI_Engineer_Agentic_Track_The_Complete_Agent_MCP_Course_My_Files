# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
import requests
import json

openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openrouter_api_key:
    print(f"Open Router API Key exists and begins {openrouter_api_key[:8]}")
else:
    print("Open Router API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-or-v1

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=openrouter_api_key,
)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
  model="google/gemma-4-31b-it:free",
  messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
  model="google/gemma-4-31b-it:free",
  messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If all Bloops are Razzles and some Razzles are Glimmers, but no Bloops are Glimmers, does it logically follow that some Razzles are not Bloops? Explain your reasoning.

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="google/gemma-4-31b-it:free",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# **Yes, it logically follows.**
#
# Here is the step-by-step reasoning:
#
# ### 1. Analyze the Premises
# *   **Premise A:** All Bloops are Razzles. (Bloops $\subseteq$ Razzles)
# *   **Premise B:** Some Razzles are Glimmers.
# *   **Premise C:** No Bloops are Glimmers.
#
# ### 2. The Logical Deduction
# To determine if some Razzles are not Bloops, we look for a specific group of Razzles that cannot possibly be Bloops.
#
# *   From **Premise B**, we know there is a group of things that are both **Razzles and Glimmers**.
# *   From **Premise C**, we know that **no Glimmer can be a Bloop**.
# *   Therefore, those specific Razzles that are Glimmers **cannot be Bloops**.
#
# ### 3. Conclusion
# Since there is at least one Razzle (the one(s) that are Glimmers) that is guaranteed not to be a Bloop, the statement **"Some Razzles are not Bloops"** is logically necessary.
#
# ***
#
# **Visual Representation (Euler Circles):**
# *   Imagine a large circle for **Razzles**.
# *   Inside that circle, place a smaller circle for **Bloops** (because all Bloops are Razzles).
# *   Now, place a circle for **Glimmers**. This circle must overlap with the **Razzles** circle (because some Razzles are Glimmers), but it must remain completely separate from the **Bloops** circle (because no Bloops are Glimmers).
# *   The area where the Glimmer circle overlaps with the Razzle circle represents Razzles that are not Bloops.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# **Yes, it logically follows.**
#
# Here is the step-by-step reasoning:
#
# ### 1. Analyze the Premises
# *   **Premise A:** All Bloops are Razzles. (Bloops $\subseteq$ Razzles)
# *   **Premise B:** Some Razzles are Glimmers.
# *   **Premise C:** No Bloops are Glimmers.
#
# ### 2. The Logical Deduction
# To determine if some Razzles are not Bloops, we look for a specific group of Razzles that cannot possibly be Bloops.
#
# *   From **Premise B**, we know there is a group of things that are both **Razzles and Glimmers**.
# *   From **Premise C**, we know that **no Glimmer can be a Bloop**.
# *   Therefore, those specific Razzles that are Glimmers **cannot be Bloops**.
#
# ### 3. Conclusion
# Since there is at least one Razzle (the one(s) that are Glimmers) that is guaranteed not to be a Bloop, the statement **"Some Razzles are not Bloops"** is logically necessary.
#
# ***
#
# **Visual Representation (Euler Circles):**
# *   Imagine a large circle for **Razzles**.
# *   Inside that circle, place a smaller circle for **Bloops** (because all Bloops are Razzles).
# *   Now, place a circle for **Glimmers**. This circle must overlap with the **Razzles** circle (because some Razzles are Glimmers), but it must remain completely separate from the **Bloops** circle (because no Bloops are Glimmers).
# *   The area where the Glimmer circle overlaps with the Razzle circle represents Razzles that are not Bloops.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Could you pick just one bussiness area that presents an Agentic AI opportunity "}]

# Then make the first call:

response = openai.chat.completions.create(
    model="openai/gpt-oss-20b:free",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
display(Markdown("## Business Idea\n" + business_idea))

# And repeat! In the next message, include the business idea within the message

messages = [{"role": "user", "content": f"Presents a pain point in this {business_idea} - something challenging that might be ripe for an Agentic solution"}]

pain_point = openai.chat.completions.create(
    model="openai/gpt-oss-20b:free",
    messages=messages
).choices[0].message.content

display(Markdown("## Pain Point\n" + pain_point))

messages = [{"role": "user", "content": f"Propose a solution to this {pain_point}"}]
solution = openai.chat.completions.create(
    model="openai/gpt-oss-20b:free",
    messages=messages
).choices[0].message.content

display(Markdown("## Solution\n" + solution))
# Out:
# ## Business Idea
# **Business Area:** *Real‑Time Inventory & Demand‑Planning for E‑Commerce & Retail*
#
# ### Why this area is a ripe fit for Agentic AI
#
# | Need | How Agentic AI Adds Value |
# |------|--------------------------|
# | **Dynamic demand forecasting** | An autonomous agent continually ingests sales, weather, social‑media, and supply‑chain data, recalculates probability distributions, and adjusts product‑level forecasts on the fly. |
# | **Automated inventory replenishment** | The same agent places, tracks, and optimizes purchase orders across multiple suppliers, negotiating price‑quality trade‑offs using reinforcement learning. |
# | **Cross‑channel promotion planning** | It models consumer sentiment and traffic patterns to decide which promotions to launch, where, and for how long, maximizing ROI while preventing stockouts or over‑stocking. |
# | **Exception handling** | When an anomaly is detected (e.g., sudden supply disruption), the agent automatically escalates, re‑routes shipments, or activates contingency inventory without human intervention. |
# | **End‑to‑end transparency** | The agent maintains a fully auditable trail of its decisions, learning signals, and policy updates, satisfying regulatory requirements and auditers. |
#
# ### How it works in practice
#
# 1. **Data Fusion Layer** – Continuous ingestion of structured (POS, ERP), semi‑structured (email, feed), and unstructured (social media, sensor) data streams.
# 2. **Embedded RL Agent** – Trained on historical and simulated environments to balance *stock‑out risk* vs. *holding costs*.
#    - *Policy*: `order_quantity = f(current_stock, forecast, forecast_uncertainty, lead_time, cost_params)`
# 3. **Human‑in‑the‑Loop Interface** – Users can set high‑level constraints (e.g., “no more than 70% understock”) and approve or override low‑impact suggestions.
# 4. **Automated Execution** – Once approved or if within safe thresholds, the agent issues purchase orders, triggers reorder requests, and schedules outbound logistics.
# 5. **Continuous Learning** – Each cycle’s outcomes feed back into the agent’s model, improving accuracy and reducing manual tuning cycles.
#
# ### Competitive Edge
#
# - **Speed**: Reallocations react in seconds, beating the manual planning cycle of days or weeks.
# - **Precision**: Multi‑objective optimization (cost, service level, carbon footprint) in a single policy.
# - **Scalability**: Add new SKUs or markets by simply extending the data pipeline; the agent self‑adjusts.
# - **Resilience**: Self‑corrective behavior (e.g., rapid re‑routing during logistics hiccups) reduces dependency on manual crisis management teams.
#
# ---
#
# **Bottom line:** Agentic AI can transform the *inventory and demand‑planning loop* from a passive, periodic task into a self‑learning, proactive partner that consistently optimizes supply‑chain economics while staying compliant and auditable. This is a high‑impact, high‑payback opportunity for companies in e‑commerce, fashion, electronics, or grocery sectors.
# ## Pain Point
# ### Pain Point in **Real‑Time Inventory & Demand‑Planning for E‑Commerce & Retail**
#
# | # | Current Reality | Why It’s Painful |
# |---|------------------|------------------|
# | 1 | **Siloed, batch‑processed forecasting** | Forecasts are updated weekly/monthly, often 1–2 weeks after the fact. By the time the next order cycle begins, the window of *actionable* data has already closed. |
# | 2 | **Manual, rule‑based reorder points** | Inventory planners set static “order‑up‑to” levels or reorder thresholds that ignore real‑time lead‑time variability, seasonal spikes, or sudden supply chain shocks. |
# | 3 | **Complex, fragmented data sources** | Sales, weather, social sentiment, supplier lead times, and logistics status live in separate systems (POS, ERP, WMS, 3PL APIs). Data wrangling is labor‑intensive and latency‑prone. |
# | 4 | **Human‑in‑the‑Loop bottleneck** | Even the best analytics dashboards require a domain expert to interpret results, make decisions, and issue orders. That extra step introduces ~50 % timing lag and variable quality. |
# | 5 | **Reactive exception handling** | Anomalies (e.g., shipment delays, supplier outages) are typically discovered only after a delivery fails or stock runs out, triggering costly manual escalation and post‑mortems. |
# | 6 | **Compliance & audit noise** | Each autonomous decision must be recorded and traceable for regulatory or internal audit teams, yet current tools lack a unified, auditable provenance chain. |
#
# ---
#
# ### Why This Pain Point Is a *Gap* That Agentic AI Can Fill
#
# | Pain | Agentic AI Strength | Impact |
# |------|--------------------|--------|
# | Batch latency | **Continuous ingestion & immediate inference** | Forecasts are updated dynamically with new data (sales, social chatter, weather) in real time. |
# | Static reorder rules | **Reinforcement‑learning driver that balances multiple objectives** | The policy learns to trade off *stock‑out risk*, *holding cost*, *carbon footprint*, and *supply‑chain lead time* on a per‑SKU basis. |
# | Fragmented data | **Unified Data‑Fusion layer** | An agent automatically pulls, cleans, and normalizes all structured/unstructured streams, delivering a single “truth” to the model. |
# | Human bottleneck | **Human‑in‑the‑Loop with confidence thresholds** | The agent proposes orders; only low‑impact changes are applied automatically, while high‑impact decisions are surfaced for review—reducing human load by ~70 % on routine orders. |
# | Reactive crisis | **Predictive anomaly detection + auto‑mitigation** | By monitoring lead‑time drift, shipment anomalies, or supply disruptions, the agent triggers re‑routing, alternate supplier bidding, or contingency stock release before a stockout occurs. |
# | Audit trails | **Fully traceable policy updates & decision logs** | Every suggestion, override, and executed order is tagged with data provenance, model version, and explainability notes, automatically collated into an audit‑ready report. |
#
# ---
#
# ### High‑Level Architecture Snapshot
#
# ```
# +---------------------+   +------------------------+   +-------------------+
# | 1. Data Fusion      |   | 2. Embedded RL Agent   |   | 3. HITO (UI/RO)   |
# |   (Kafka → dbt→ db)|-->|   (Policy: Qty=f(...))|-->|   (Model views)   |
# +---------------------+   +------------------------+   +-------------------+
#            |                           |                       |
#            | 4. Action Execution (PO,   | 5. Feedback loop:     |
#            |    Transport orders)       |    Exec → Outcome     |
#            +--------------+-------------+-----------------------+
#                           |
#                   6. Audit & Monitoring
# ```
#
# ---
#
# ### The “Bottom Line”
#
# - **Speed:**  Orders and inventory adjustments occur in **seconds**, not days.
# - **Precision:**  Multi‑objective RL leads to **10–20 %** lower total costs while maintaining service levels.
# - **Scalability:**  New SKUs or markets imply *no* new rules—just updated data streams.
# - **Resilience:**  The agent self‑‑applies contingency plans, cutting crisis‑management effort by >50 %.
#
# In short, the most *painful* part of inventory & demand planning—handling real‑time, noisy, and siloed data to make autonomous decisions—fits perfectly into the agentic AI paradigm. By lowering the friction of data, automating decision loops, and embedding transparency, businesses can transform an antiquated, manual control room into a dynamic, self‑learning supply‑chain hero.
# ## Solution
# ## A One‑Click, End‑to‑End “Agentic‑Supply‑Chain” Platform
# *(Real‑Time Inventory & Demand‑Planning for E‑Commerce & Retail)*
#
# | Step | What the Agent Does | How the Pain Point vanishes |
# |------|--------------------|-----------------------------|
# | **1. Ingest & Fuse** | Kafka → FHIR‑style schema → *Unified Edge Store* (Delta Lake).  A lightweight Python micro‑service reads all POS feeds, weather APIs, 3PL alerts, social‑media sentiment, and supplier dashboards in real time, normalises to a single fact table. | Fragmented data → single source of truth, zero‑latency joins. |
# | **2. Feature Factory** | dbt‑in‑action: incremental transforms, lag‑adjustments, rolling aggregates, trend‑extraction, and proxy‑sentiment scores. Export to a Snowflake “Data Lakehouse” view that the policy consumes. | Manual wrangling disappears; data ready for inference 100 ms after arrival. |
# | **3. RL Agent + Anomaly Engine** | **Hybrid Architecture**<br>• **Reinforcement‑Learning Policy** (Deep‑Deterministic Policy Gradient, DDPG) that outputs *reorder quantity* per SKU per location each minute. Input: recent sales, inventory, lead‑time confidence, carbon‑intensity, and external features. <br>• **Bayesian‑Online Change‑Detection** on lead‑time and shipment batches; upon drift > 3σ, auto‑trigger re‑routing or stock‑reserve. | Batch latency ≤ 30 s → decisions are fresh. Static rules replaced by a learning model that balances multiple objectives. |
# | **4. Human‑in‑the‑Loop (HITO) Concierge** | A React‑based UI shows: <br>• *Confidence heat‑map* (expected fill‑rate, expected stock‑out risk).<br>• *Explainability panel* (SHAP‑style, rule‑list, meta‑features).<br>• *Override/approve button* for high‑impact actions (≥ 10 % deviation from base policy). | Human bottleneck shrinks to a 70 % reduction on routine orders, with only critical decisions requiring a click. |
# | **5. Seamless Execution Layer** | Rest‑API that writes a *Purchase Order* into the supplier portal (via e‑DI, EDIFACT, or custom SaaS). Or triggers a *Transport Request* in WMS. All actions are idempotent. | Automation eliminates the 50 % time lag; orders placed inside seconds. |
# | **6. Cloud‑Native Audit Trail** | Immutable JSON logs in S3/GCS, tagged with: <br>• Request ID, Agent Version, Feature Snapshot, Decision‑Trace, Confidence, Human action, Outcome. CloudWatch/Datadog dashboards auto‑fluentet to Snowflake. | Zero‑manual reporting; a single query produces a regulatory‑ready audit file. |
# | **7. Continuous Learning Loop** | Every executed order feeds back: <br>• *Execution Outcome* (on‑time, delayed, cancelled).<br>• *Service‑level* (sell‑through, back‑order).<br>• *Cost* (COGS, holding, transport). The RL agent’s replay buffer is retrained nightly, with a stage‑validation gate. | The agent never “stagnates”; it adapts to new SKUs or seasonal shifts with zero rule‑tuning. |
#
# ---
#
# ### Why This Beats the Status Quo
#
# | Pain | Current Fixes | Proposed Fix | Gain |
# |------|---------------|--------------|------|
# | **Batch Latency** | Weekly spreadsheet recalcs | 30‑second inference | Reduce data‑windup from weeks to real‑time. |
# | **Static Rules** | XYZ reorder point table | RL policy learning over 30‑night horizon | Cut stock‑out risk by 25 % while holding cost falls 15 %. |
# | **Fragmentation** | Manual ETL + “Data Lake” | Real‑time data‑fusion pipeline | 0 % data latency; one truth table. |
# | **Human Bottleneck** | Email‑based PO review | Auto‑approve 70 % of low‑confidence orders | Free planners for strategic work. |
# | **Reactive Exceptions** | Post‑mortem reports | Anomaly broker that auto‑switches supplier or calls for reserve | 50 % fewer stock‑out incidents. |
# | **Audit Noise** | Spreadsheet + email trails | Immutable logs + audit‑ready dashboard | 100 % compliance; faster audit closure. |
#
# ---
#
# ### Capabilities Dashboard (What You’ll See)
#
# | Metric | Target | Current | Post‑Agent |
# |--------|--------|---------|-----------|
# | Order Cycle Time | < 1 min | 5 days | 30 s |
# | Stock‑Out Risk | < 2 % | 5–8 % | 1.5 % |
# | Inventory Holding Cost | – | $2.1 M | $1.7 M |
# | Planner's Strategic Time | 10 % of day | 70 % of day | 30 % of day |
# | Anomaly Response Time | < 5 min | 1 day | 2 min |
# | Audit Turn‑around | 3 weeks | 2 months | 2 days |
#
# ---
#
# ### Deployment Roadmap (6 Months)
#
# | Phase | Core Activities | Deliverables |
# |-------|-----------------|--------------|
# | 0 – Baseline | Prod‑ready API, data ingestion, data lake | L1 ingestion pipeline |
# | 1 – Agent Core | DDPG + Bayesian drift engine, DBT transforms | 1‑min RL policy + anomaly engine |
# | 2 – HITO UI | Confidence & override UI, explanation layer | Pilot HITO for 2 warehouses |
# | 3 – Execution | PO integration, 3PL alerts | Automated PO/Transport cycle |
# | 4 – Audit & Analytics | Immutable logs, audit‑ready dashboards | Full audit suite |
# | 5 – Scale | 10 % more SKUs + 3rd market | Zero new rule creation |
# | 6 – Optimization | Meta‑RL for multi‑objective learning | 20 % cost reduction benchmark |
#
# ---
#
# ## Bottom Line
#
# By **wrapping inventory & demand planning in an agentic framework**—real‑time ingestion, continuous RL inference, automated anomaly mitigation, and a human‑concierge UI—you turn a batch‑driven, siloed control room into a **dynamic, self‑learning supply‑chain engine**. The result: orders in seconds, policies that evolve with data, 10–20 % lower total cost, and a single, fully auditable provenance chain that satisfies regulators and auditors alike.
