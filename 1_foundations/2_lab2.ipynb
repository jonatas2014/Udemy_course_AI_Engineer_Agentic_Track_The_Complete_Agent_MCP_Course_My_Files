# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openrouter_api_key = os.getenv('OPENROUTER_API_KEY')
"""
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
"""
if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:8]}")
else:
    print("OpenRouter API Key not set")
''' 
if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:8]}")
else:
    print("OpenRouter API Key not set")
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
'''
# Out:
# OpenRouter API Key exists and begins sk-or-v1
# ' \nif openrouter_api_key:\n    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:8]}")\nelse:\n    print("OpenRouter API Key not set")\nif anthropic_api_key:\n    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")\nelse:\n    print("Anthropic API Key not set (and this is optional)")\n\nif google_api_key:\n    print(f"Google API Key exists and begins {google_api_key[:2]}")\nelse:\n    print("Google API Key not set (and this is optional)")\n\nif deepseek_api_key:\n    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")\nelse:\n    print("DeepSeek API Key not set (and this is optional)")\n\nif groq_api_key:\n    print(f"Groq API Key exists and begins {groq_api_key[:4]}")\nelse:\n    print("Groq API Key not set (and this is optional)")\n'

# %%
request = "Develop a guide to a newbie at spec driven development, to develop a chat application aimed to be deployed "
request += "on the Google Cloud Platform that will emulate a data analyst acessing big data saved on Big Query tables to respond questions about the data. The llm model to be used in the chat application is restricted to be a Gemini model from Vertex. "
request += "The guide should include the steps to create the necessary prompts to create this application, the tools that can be used, and best practices for spec driven development in this context."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Develop a guide to a newbie at spec driven development, to develop a chat application aimed to be deployed on the Google Cloud Platform that will emulate a data analyst acessing big data saved on Big Query tables to respond questions about the data. The llm model to be used in the chat application is restricted to be a Gemini model from Vertex. The guide should include the steps to create the necessary prompts to create this application, the tools that can be used, and best practices for spec driven development in this context.'}]

# %%
openai = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=openrouter_api_key,
)
'''
response = openai.chat.completions.create(
    model="openai/gpt-oss-20b:free",
    messages=messages,
)

question = response.choices[0].message.content
print(question)
'''
# Out:
# '\nresponse = openai.chat.completions.create(\n    model="openai/gpt-oss-20b:free",\n    messages=messages,\n)\n\nquestion = response.choices[0].message.content\nprint(question)\n'

# %%
model_competitors = []
answers = []
#messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "anthropic/claude-opus-4.7"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
model_competitors.append(model_name)
answers.append(answer)
# Out:
# # Beginner's Guide to Spec-Driven Development: Building a BigQuery Data Analyst Chat Application on GCP
#
# ## Table of Contents
# 1. [What is Spec-Driven Development?](#what-is-spec-driven-development)
# 2. [Project Overview](#project-overview)
# 3. [Tools You'll Need](#tools-youll-need)
# 4. [The Spec-Driven Workflow](#the-spec-driven-workflow)
# 5. [Step-by-Step Prompt Creation](#step-by-step-prompt-creation)
# 6. [Best Practices](#best-practices)
# 7. [Common Pitfalls](#common-pitfalls)
#
# ---
#
# ## What is Spec-Driven Development?
#
# Spec-Driven Development (SDD) is a methodology where you write **detailed specifications first**, then use those specs to drive code generation (often with AI assistants). Instead of diving into code, you:
#
# 1. **Define WHAT** the system should do (requirements)
# 2. **Define HOW** it should be structured (design)
# 3. **Break down into TASKS** (implementation plan)
# 4. **Generate code** guided by these specs
#
# ...

# %%
model_name = "anthropic/claude-sonnet-4.5"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
model_competitors.append(model_name)
answers.append(answer)

'''
claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
'''
# Out:
# # Balancing Privacy and Transparency: A Systems Approach
#
# ## Core Design Principles
#
# **Contextual Integrity Framework**
# Information flows appropriately when they respect the context: medical records follow different rules than corporate filings. The system would enforce context-specific norms rather than blanket policies.
#
# **Tiered Access Architecture**
# - **Public layer**: Aggregated, anonymized data
# - **Credentialed layer**: Researchers/journalists with accountability mechanisms
# - **Regulatory layer**: Full access with audit trails
# - **Emergency override**: Court-authorized with time limits
#
# ## Key Mechanisms
#
# **Technical Safeguards**
# - Differential privacy for statistics (adding mathematical noise to prevent re-identification)
# - Zero-knowledge proofs (proving something is true without revealing the underlying data)
# - Smart contracts for automated, logged access decisions
# - Homomorphic encryption (analyzing encrypted data without decrypting)
#
# ...

# %%
#gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "google/gemini-2.5-flash"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
model_competitors.append(model_name)
answers.append(answer)
# Out:
# Designing a system that balances personal privacy with public transparency, especially with sensitive information, is a complex challenge requiring careful consideration of technical, legal, and ethical frameworks. Here's a comprehensive approach:
#
# ## System Design Principles
#
# The inherent tension between privacy and transparency necessitates a design that incorporates both by default, not as afterthoughts.
#
# 1.  **Privacy by Design & Default:**
#     *   **Data Minimization:** Collect only the absolutely necessary data. Avoid collecting "just in case" information.
#     *   **Purpose Limitation:** Specify the exact purpose for which each piece of data is collected and processed. Prohibit re-purposing without consent or legal basis.
#     *   **Anonymization & Pseudonymization:** Prioritize these techniques for public disclosure.
# ...

# %%
#deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek/deepseek-v3.2"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
model_competitors.append(model_name)
answers.append(answer)
# Out:
# # Designing a System Balancing Privacy, Transparency & Security
#
# ## Core Architecture Principles
#
# ### 1. **Tiered Access Framework**
# - **Public Layer:** Non-sensitive information with minimal privacy impact
# - **Verified Regulator Layer:** Authorized oversight with strict audit trails
# - **Protected Oversight Layer:** Sensitive data accessible only under specific conditions (court orders, legislative mandates)
# - **Emergency Access Protocol:** Limited-time access during crises with post-event review
#
# ### 2. **Technical Implementation**
#
# **Data Classification Engine:**
# - AI-assisted categorization of information sensitivity
# - Multi-factor risk assessment (privacy impact, public interest, potential harm)
#
# **Dynamic Redaction System:**
# - Context-aware masking of personally identifiable information
# - Reversible redaction with cryptographic key management for authorized access
#
# **Access Control Mechanism:**
# - Multi-party authorization for sensitive data
# ...

# %%
# Updated with the latest Open Source model from OpenAI

#groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b:free"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
model_competitors.append(model_name)
answers.append(answer)
# Out:
# ## 1. Overview – A “Privacy‑by‑Transparency” Architecture
#
# We can think of the system as a **layered data‑governance platform** that sits between every data‑originating component (sensors, internal applications, third‑party feeds) and every data‑consumer (regulators, journalists, auditors, the public).
#
# | Layer | Core Goal | Typical Controls | Example Tech |
# |-------|-----------|------------------|--------------|
# | **1️⃣ Ingestion / Classification** | Identify what data is collected and how sensitive it is. | Automated data‑type tagging, sensitivity scoring (PII, trade‑secret, national‑security, etc.). | ML‑based data‑catalogue (e.g., Google Cloud Data Catalog), privacy‑impact‑assessment (PIA) templates. |
# | **2️⃣ Policy Engine** | Translate legal/organizational rules into machine‑enforceable policies. | Policy‑as‑code (OPA/Rego), dynamic rule sets (e.g., “health data → only regulator A may view, redacted for public”). | Open Policy Agent, AWS IAM Policy Simulator. |
# ...

# %%
# Save the model_competitors and answers lists to a persistent file
import pickle

# Define the file path to save the data
output_file = "model_competitors_and_answers.pkl"

# Save the data using pickle
with open(output_file, "wb") as f:
    pickle.dump({"model_competitors": model_competitors, "answers": answers}, f)

print(f"Data saved to {output_file}")

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 132 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 2.7 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 7.7 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  10 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  11 MB/2.0 GB                  pulling manifest
# ...

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

request = "Fale sobre um questionamento filosófico moderno"
messages = [{"role": "user", "content": request}]

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
#competitors.append(model_name)
#answers.append(answer)
# Out:
# Um dos questionamentos filosóficos mais relevantes e complexos do século XXI é aquele relacionado à a natureza da realidade humana e sua relação com o mundo físico. Em resumo, podemos chamar esse questionamento de "A Busca pela Autenticidade Humana no Mundo Digital".
#
# Aqui está uma abordagem mais detalhada sobre esse tema:
#
# **Contexto**: Com o avanço tecnológico, especialmente com o surgimento da internet e das redes sociais, a forma como nos relacionamos conosco mesmos e com os outros muda radicalmente. A cada dia, estamos expostos à uma quantidade cada vez maior de informações que nos dizem quem somos, o que somos fazendo, o que queremos, etc.
#
# **Questionamento filosófico**: Em meio à constante exposição a essas informações e ao fluxo constante de dados, questionamos: qual é a realidade autêntica da nossa própria individualidade humana? Como podemos saber conosco mesmos quando estamos expostos a tantas opções e falsificações?
#
# ...

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
